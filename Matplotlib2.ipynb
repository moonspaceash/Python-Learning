# %% [markdown]
# <a href="https://colab.research.google.com/github/moonspaceash/Python-Learning/blob/main/Matplotlib2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download below dataset again(link given in chat) and create all possible *chart*

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166 -O vgsales.csv
# Out:
# --2023-06-20 01:22:24--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 18.67.66.76, 18.67.66.49, 18.67.66.77, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|18.67.66.76|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2041483 (1.9M) [text/plain]
# Saving to: ‘vgsales.csv’
#
# vgsales.csv         100%[===================>]   1.95M  --.-KB/s    in 0.02s
#
# 2023-06-20 01:22:24 (117 MB/s) - ‘vgsales.csv’ saved [2041483/2041483]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('vgsales.csv')
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16652.000000  16381.000000  16652.000000  16652.000000  16652.000000
# mean    8283.409620   2006.390513      2.752314      1.996875      2.499677
# std     4794.471477      5.863261      1.327002      1.322972      1.164023
# min        1.000000   1980.000000      0.140000      0.010000      0.000000
# 25%     4129.750000   2003.000000      1.781124      1.087977      1.781124
# 50%     8273.500000   2007.000000      2.697415      1.714664      2.480356
# 75%    12436.250000   2010.000000      3.677290      2.795123      3.176299
# max    16600.000000   2020.000000      8.725452      8.367985     12.722984
#
#         Other_Sales  Global_Sales
# count  16652.000000  16652.000000
# mean       1.151829      8.457873
# std        1.054813      3.717756
# min       -0.474276      0.240000
# 25%        0.394830      5.580341
# 50%        0.491870      7.536614
# 75%        1.781124     11.227334
# max        7.358020     30.555862

# %%
data['Name'].value_counts()
# Out:
# Ice Hockey                                       41
# Baseball                                         17
# Need for Speed: Most Wanted                      12
# Ratatouille                                       9
# FIFA 14                                           9
#                                                  ..
# Indy 500                                          1
# Indy Racing 2000                                  1
# Indycar Series 2005                               1
# inFAMOUS                                          1
# Zyuden Sentai Kyoryuger: Game de Gaburincho!!     1
# Name: Name, Length: 11493, dtype: int64

# %%
ih = data.loc[data['Name'] == 'Ice Hockey']

# %%
sns.lineplot(x='Year', y = 'NA_Sales', data = ih)
# Out:
# <Axes: xlabel='Year', ylabel='NA_Sales'>

# %%
plt.title('Ice hockey sales trend')
plt.xlabel('Year')
plt.ylabel('Sales')
sns.lineplot(x='Year', y = 'NA_Sales', data = ih)
plt.show()

# %%
plt.title('Ice hockey sales trend')
plt.xlabel('Year')
plt.ylabel('Sales')
sns.lineplot(x='Year', y = 'NA_Sales', data = ih, color = 'k')
plt.show()

# %%
plt.title('Ice hockey sales trend')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.xlim(left= 1995, right = 2010)
sns.lineplot(x='Year', y = 'NA_Sales', data = ih, color = 'k')
plt.show()

# %%
baseball = data.loc[data['Name'] == 'Baseball']

# %%
sns.lineplot(x='Year', y = 'NA_Sales', data = baseball)
# Out:
# <Axes: xlabel='Year', ylabel='NA_Sales'>

# %%
sns.lineplot(x='Year', y = 'NA_Sales', data = ih, label = 'Ice hockey')
sns.lineplot(x='Year', y = 'NA_Sales', data = baseball, label = 'Baseball')
# Out:
# <Axes: xlabel='Year', ylabel='NA_Sales'>

# %%
sns.lineplot(x='Year', y = 'NA_Sales', data = ih)
sns.lineplot(x='Year', y = 'NA_Sales', data = baseball)
plt.legend(['Ice hockey','Baseball'])
plt.show()

# %%
sns.lineplot(x='Year', y='NA_Sales', data=ih)
sns.lineplot(x='Year', y='NA_Sales', data=baseball, color = 'k')
plt.legend(['Ice Hockey','Baseball'])
plt.show()

# %%
sns.lineplot(x='Year', y='NA_Sales', data=ih)
sns.lineplot(x='Year', y='NA_Sales', data=baseball)
plt.legend(['Ice Hockey','Baseball'], loc = (-0.5,0.5))
plt.show()

# %%
sns.lineplot(x='Year', y='NA_Sales', data=ih)
sns.lineplot(x='Year', y='NA_Sales', data=baseball, color = 'k')
plt.legend(['Ice Hockey','Baseball'], loc='lower right', ncol = 2, frameon = False)
plt.show()

# %%
print(max(ih['NA_Sales']))
# Out:
# 0.9

# %%
sns.lineplot(x='Year', y='NA_Sales', data=ih)
sns.lineplot(x='Year', y='NA_Sales', data=baseball)
plt.legend(['Ice Hockey','Baseball'], loc='lower left')
plt.text(2002, max(ih['NA_Sales']), 'Max ice hockey sales')
plt.grid()
plt.show()

# %%
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
sns.lineplot(data = data, x ='Rank', y = 'Global_Sales')
# Out:
# <Axes: xlabel='Rank', ylabel='Global_Sales'>

# %%
sns.scatterplot(data=data, x='Rank', y ='Global_Sales')
# Out:
# <Axes: xlabel='Rank', ylabel='Global_Sales'>

# %%
top3_pub = data['Publisher'].value_counts().index[:3]

# %%
top3_pub
# Out:
# Index(['Electronic Arts', 'Activision', 'Namco Bandai Games'], dtype='object')

# %%
top3_gen = data['Genre'].value_counts().index[:3]

# %%
top3_gen
# Out:
# Index(['Action', 'Sports', 'Misc'], dtype='object')

# %%
top3_plat = data['Platform'].value_counts().index[:3]

# %%
top3_plat
# Out:
# Index(['DS', 'PS2', 'PS3'], dtype='object')

# %%
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
top3_data = data.loc[(data["Publisher"].isin(top3_pub)) & (data["Platform"].isin(top3_plat)) & (data['Genre'].isin(top3_gen))]

# %%
top3_data.head(20)
# Out:
#       Rank                                            Name Platform    Year  \
# 2    14279               .hack: Sekai no Mukou ni + Versus      PS3  2012.0
# 13    2742                                   [Prototype 2]      PS3  2012.0
# 16    1604                                     [Prototype]      PS3  2009.0
# 19    1741                          007: Quantum of Solace      PS3  2008.0
# 21    4501                          007: Quantum of Solace      PS2  2008.0
# 22    9320                          007: Quantum of Solace       DS  2008.0
# 64    3407                             2002 FIFA World Cup      PS2  2002.0
# 67    1614                2010 FIFA World Cup South Africa      PS3  2010.0
# 71    2903                      2014 FIFA World Cup Brazil      PS3  2014.0
# 87    8848             3rd Super Robot Wars Z: Tengoku-Hen      PS3  2015.0
# 166   2764                     Ace Combat: Assault Horizon      PS3  2011.0
# 180   3969                            Activision Anthology      PS2  2002.0
# 343   9722               All Kamen Rider: Rider Generation       DS  2011.0
# 344  10591             All Kamen Rider: Rider Generation 2       DS  2012.0
# 457   8546                             Angry Birds Trilogy      PS3  2012.0
# 563   3567                                  Arena Football      PS2  2006.0
# 854   4049  Bakugan Battle Brawlers: Defenders of the Core       DS  2010.0
# 856   8458  Bakugan Battle Brawlers: Defenders of the Core      PS3  2010.0
# 859   1393                        Bakugan: Battle Brawlers       DS  2009.0
# 861   4562                        Bakugan: Battle Brawlers      PS2  2009.0
#
#       Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2    Action  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693
# 13   Action          Activision  3.978349  3.727034  0.848807     2.792725
# 16   Action          Activision  4.569217  4.108402  1.187272     3.339269
# 19   Action          Activision  4.156030  4.346074  1.087977     3.390562
# 21   Action          Activision  3.228043  2.738800  2.585598     3.652926
# 22   Action          Activision  2.792725  0.394830  2.854554     0.394830
# 64   Sports     Electronic Arts  3.439352  3.228043  3.167419     2.186589
# 67   Sports     Electronic Arts  3.796027  4.553713  2.340740     3.485872
# 71   Sports     Electronic Arts  3.102880  4.058391  0.394830     3.167419
# 87   Action  Namco Bandai Games  1.354020  1.097264  3.102880     0.394830
# 166  Action  Namco Bandai Games  3.796027  3.167419  3.485872     2.340740
# 180    Misc          Activision  3.613706  3.339269  3.179667     2.186589
# 343  Action  Namco Bandai Games  1.597926  0.925676  2.879736     0.394830
# 344  Action  Namco Bandai Games  0.454335  1.364384  2.697415     0.401761
# 457  Action          Activision  2.879736  1.087977  2.308154     1.087977
# 563  Sports     Electronic Arts  3.727034  3.485872  3.078957     2.340740
# 854  Action          Activision  4.132499  1.087977  1.087977     1.493442
# 856  Action          Activision  3.033887  0.394830  2.576329     1.087977
# 859  Action          Activision  5.239017  1.087977  2.022301     2.592054
# 861  Action          Activision  3.439352  3.167419  3.788465     2.004268
#
#      Global_Sales
# 2        4.982552
# 13      11.447989
# 16      13.181205
# 19      12.980643
# 21      11.780257
# 22       6.529231
# 64      12.021403
# 67      14.176352
# 71      10.723520
# 87       6.130003
# 166     12.790058
# 180     12.249544
# 343      5.838466
# 344      4.956249
# 457      7.477676
# 563     12.623442
# 854      7.801896
# 856      7.484536
# 859     10.762764
# 861     12.627526

# %%
sns.countplot(x='Publisher', hue = 'Platform', data = top3_data)
# Out:
# <Axes: xlabel='Publisher', ylabel='count'>

# %%
break : 8 15 am

# %% [markdown]
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/545/original/download_%281%29.png?1671006217)

# %%
sns.boxplot(x='Publisher', y='Global_Sales', data=top3_data)
plt.xticks(rotation=90,fontsize=12)
plt.yticks(fontsize=12)
plt.title('Sales for top3 publisher', fontsize=15)

plt.show()

# %%
sns.barplot(data=top3_data, x= "Genre", y = "Global_Sales", estimator=np.mean)
# Out:
# <Axes: xlabel='Genre', ylabel='Global_Sales'>

# %%
fig = plt.figure(figsize=(15,10))
sns.scatterplot(data = top3_data, x = 'NA_Sales', y = 'EU_Sales')
fig.subtitle('Main title')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-7c3f431724dc> in <cell line: 3>()
#       1 fig = plt.figure(figsize=(15,10))
#       2 sns.scatterplot(data = top3_data, x = 'NA_Sales', y = 'EU_Sales')
# ----> 3 fig.subtitle('Main title')
#       4 plt.show()
#
# AttributeError: 'Figure' object has no attribute 'subtitle'

# %%
sns.scatterplot(data=data, x='Rank', y ='Global_Sales')

# %%
top3_data['NA_Sales']
# Out:
# 2        1.145709
# 13       3.978349
# 16       4.569217
# 19       4.156030
# 21       3.228043
#            ...
# 16438    1.087977
# 16479    2.186589
# 16601    2.340740
# 16636    2.697415
# 16640    2.592054
# Name: NA_Sales, Length: 617, dtype: float64

# %%
fig = plt.figure(figsize=(15,10))
plt.subplot(1,3,1)
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=top3_data)

plt.subplot(1,3,3)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color = 'r')

fig.suptitle('Main title')
# Out:
# Text(0.5, 0.98, 'Main title')

# %%
fig, ax = plt.subplots(2, 2, figsize=(15,10))
ax[0,0].scatter(top3_data['NA_Sales'], top3_data['EU_Sales'])
ax[0,1].scatter(top3_data['NA_Sales'], top3_data['JP_Sales'])
ax[1,0].scatter(top3_data['NA_Sales'], top3_data['Other_Sales'])
ax[1,1].scatter(top3_data['NA_Sales'], top3_data['Global_Sales'])

# %%
ax
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20,12)).suptitle("NA Sales vs regions",fontsize=20)
# Using a 2x3 subplot
plt.subplot(2, 3, 1)
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=top3_data)


plt.subplot(2, 3, 3)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='red')


plt.subplot(2, 3, 4)
sns.scatterplot(x='NA_Sales', y='Other_Sales', data=top3_data, color='green')

plt.subplot(2, 3, 6)
sns.scatterplot(x='NA_Sales', y='Global_Sales', data=top3_data, color='orange')

plt.show()

# %%
plt.figure(figsize=(20,12)).suptitle("NA Sales vs regions",fontsize=20)
# Using a 2x3 subplot
plt.subplot(2, 3, 1)
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=top3_data)
plt.title('NA vs EU Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('EU', fontsize=12)

plt.subplot(2, 3, 3)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='red')
plt.title('NA vs JP Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('JP', fontsize=12)


plt.subplot(2, 3, 4)
sns.scatterplot(x='NA_Sales', y='Other_Sales', data=top3_data, color='green')
plt.title('NA vs Other Region Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Other', fontsize=12)

plt.subplot(2, 3, 6)
sns.scatterplot(x='NA_Sales', y='Global_Sales', data=top3_data, color='orange')
plt.title('NA vs Global Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Global', fontsize=12)

plt.show()

# %%
plt.figure(figsize=(20,12)).suptitle("Video Games Sales Dashboard",fontsize=20)
# Using a 2x3 subplot
plt.subplot(2, 3, 1)
sns.scatterplot(x='NA_Sales', y='EU_Sales', data=top3_data)
plt.title('NA vs EU Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('EU', fontsize=12)



plt.subplot(2, 3, 3)
sns.scatterplot(x='NA_Sales', y='JP_Sales', data=top3_data, color='red')
plt.title('NA vs JP Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('JP', fontsize=12)

# Countplot of publishers
plt.subplot(1,3,2)
sns.countplot(x='Publisher', data=top3_data)
plt.title('Count of games by each Publisher', fontsize=12)
plt.xlabel('Publisher', fontsize=12)
plt.ylabel('Count of games', fontsize=12)


plt.subplot(2, 3, 4)
sns.scatterplot(x='NA_Sales', y='Other_Sales', data=top3_data, color='green')
plt.title('NA vs Other Region Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Other', fontsize=12)

plt.subplot(2, 3, 6)
sns.scatterplot(x='NA_Sales', y='Global_Sales', data=top3_data, color='orange')
plt.title('NA vs Global Sales', fontsize=12)
plt.xlabel('NA', fontsize=12)
plt.ylabel('Global', fontsize=12)

plt.show()
